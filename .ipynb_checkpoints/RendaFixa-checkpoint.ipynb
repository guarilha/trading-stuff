# %%
import json 
import pandas as pd
from datetime import datetime, date
import math

# %%
with open("data.json", "r") as read_file:
    data = json.load(read_file)

with open("cred-privado.json", "r") as read_file:
    cred = json.load(read_file)

instruments = data['data'] + cred['data']

# %%
df = pd.DataFrame.from_dict(instruments)
df = df.loc[df['guaranteeFGC']]

# %%
with open("inputs.json", "r") as read_file:
    inputs = json.load(read_file)
    
cdi = inputs["CDI"]
ipca = inputs["IPCA"]

# %%
exclude= ["BANCO MASTER S/A"]

df['exclude'] = df.nickName.str.contains('|'.join(exclude))
df = df.loc[df['exclude'] == False]
del df['exclude']

# %%
df['raw_yield'] = df['fee'].str.replace(" CDI", "")
df['raw_yield'] = df['raw_yield'].str.replace(",", ".")
df['raw_yield'] = df['raw_yield'].str.replace("%", "")
df['raw_yield'] = df['raw_yield'].str.replace("+", "", regex=False)
df['raw_yield'] = df['raw_yield'].str.replace("IPC-A", "")
df['raw_yield'] = df['raw_yield'].astype(float)

# %%
df['maturityDate'] = pd.to_datetime(df['maturityDate'])
df['days'] = (df['maturityDate'] - datetime.now()).dt.days
df['yearsToMaturity'] = df['days'] / 365
df['yearsToMaturity'] = df['yearsToMaturity'].apply(math.ceil)

# %%
df['taxes'] = 22.5
df.loc[df['days'] > 180, 'taxes'] = 20.0
df.loc[df['days'] > 360, 'taxes'] = 17.5
df.loc[df['days'] > 720, 'taxes'] = 15.0
df.loc[df['product'] == 'LCA', 'taxes'] = 0.0
df.loc[df['product'] == 'LCI', 'taxes'] = 0.0
df.loc[df['product'] == 'CRI', 'taxes'] = 0.0
df.loc[df['product'] == 'CRA', 'taxes'] = 0.0

# %%
df['yield'] = (1 - df['taxes']/100.0)*df['raw_yield']

# %%
df['minInvestment'] = df['minimumQuantityForApplication'] * df['puMinValue']
df['available'] = df['quantityAvailable'] * df['puMinValue']

# %%
df = df.sort_values(by=['yearsToMaturity','yield'], ascending=False)

# %%
cols = ['nickName', 'fee', 'yield', 'yearsToMaturity', 'daysToMaturity']

# %%
pos = df.loc[df['indexers']=='Pós-fixado']
pos = pos.loc[df['yield'] > 100]

# %%
pre = df.loc[df['indexers']=='Pré-fixado']
pre = pre.loc[df['yield'] > cdi]

# %%
infl = df.loc[df['indexers']=='Inflação']
infl = infl.loc[df['yield'] > 6.2]

# %%
def best_options(_data, _years):
    return _data.loc[df['yearsToMaturity'] == _years]
    
print(best_options(pos, 3)[cols])
best_options(pos, 4)
# Out:
#                                       nickName          fee     yield  \
# 1360      CDB BANCO RCI BRASIL S.A. - DEZ/2024     120% CDI  102.0000
# 1363        CDB BANCO DIGIMAIS S.A. - JUL/2025     120% CDI  102.0000
# 1367           CDB EMPRESTA CAPITAL - JUL/2025     119% CDI  101.1500
# 1368                     CDB Semear - JUL/2025     119% CDI  101.1500
# 1369            CDB WILL FINANCEIRA - JUL/2025   118,5% CDI  100.7250
# 1372  CDB PERNAMBUCANAS FINANCIADOR - JUL/2025  118,25% CDI  100.5125
#
#       yearsToMaturity  daysToMaturity
# 1360                3             878
# 1363                3            1094
# 1367                3            1094
# 1368                3            1094
# 1369                3            1094
# 1372                3            1094
#                                       nickName maturityDate          fee  \
# 1350  CDB PERNAMBUCANAS FINANCIADOR - JAN/2026   2026-01-16     125% CDI
# 1354  CDB PERNAMBUCANAS FINANCIADOR - ABR/2026   2026-04-27     125% CDI
# 1356  CDB PERNAMBUCANAS FINANCIADOR - JAN/2026   2026-01-20     125% CDI
# 1359        CDB BANCO DIGIMAIS S.A. - JUL/2026   2026-07-05     122% CDI
# 1362            CDB WILL FINANCEIRA - DEZ/2025   2025-12-05     120% CDI
# 1364                     CDB Semear - JUL/2026   2026-07-05     120% CDI
# 1365            CDB WILL FINANCEIRA - DEZ/2025   2025-12-13     120% CDI
# 1366  CDB PERNAMBUCANAS FINANCIADOR - JUL/2026   2026-07-05  119,25% CDI
# 1370            CDB WILL FINANCEIRA - JUL/2026   2026-07-05   118,5% CDI
#
#       minimumQuantityForApplication   puMinValue product qualifiedInvestor  \
# 1350                              1  1025.736214     CDB                 N
# 1354                              1  1005.020711     CDB                 N
# 1356                              1  1023.992912     CDB                 N
# 1359                              1  1000.000000     CDB                 N
# 1362                              1  1045.869674     CDB                 N
# 1364                              1  1000.000000     CDB                 N
# 1365                              1  1028.697761     CDB                 N
# 1366                              1  1000.000000     CDB                 N
# 1370                              1  1000.000000     CDB                 N
#
#         indexers incentive ratingName  ... originCode  isCampaign riskScore  \
# 1350  Pós-fixado         N       None  ...          2       False         5
# 1354  Pós-fixado         N       None  ...          2       False         5
# 1356  Pós-fixado         N       None  ...          2       False         5
# 1359  Pós-fixado         N       BBB-  ...          0       False         5
# 1362  Pós-fixado         N       None  ...          2       False         5
# 1364  Pós-fixado         N       None  ...          0       False         5
# 1365  Pós-fixado         N       None  ...          2       False         5
# 1366  Pós-fixado         N       None  ...          0       False         5
# 1370  Pós-fixado         N       None  ...          0       False         5
#
#      raw_yield  daysToMaturity yearsToMaturity  taxes     yield minInvestment  \
# 1350    125.00            1289               4   15.0  106.2500   1025.736214
# 1354    125.00            1390               4   15.0  106.2500   1005.020711
# 1356    125.00            1293               4   15.0  106.2500   1023.992912
# 1359    122.00            1459               4   15.0  103.7000   1000.000000
# 1362    120.00            1247               4   15.0  102.0000   1045.869674
# 1364    120.00            1459               4   15.0  102.0000   1000.000000
# 1365    120.00            1255               4   15.0  102.0000   1028.697761
# 1366    119.25            1459               4   15.0  101.3625   1000.000000
# 1370    118.50            1459               4   15.0  100.7250   1000.000000
#
#          available
# 1350  3.077209e+03
# 1354  8.040166e+03
# 1356  1.228791e+04
# 1359  3.000000e+07
# 1362  7.844023e+04
# 1364  3.000000e+06
# 1365  6.377926e+04
# 1366  9.347000e+06
# 1370  5.000000e+05
#
# [9 rows x 30 columns]

# %%
def tax_free_yield(_yield, _date):
    d = date.fromisoformat(_date)
    days = (d - date.today()).days
    tax = 0.225
    if days > 720:
        tax = 0.150
    elif days > 360:
        tax = 0.175
    elif days > 180:
        tax = 0.200
    return _yield * (1 - tax)

# %%
tax_free_yield(118, '2029-07-06')
